# %%
import pandas as pd

# %%
notas = pd.read_csv('arquivos/notas.csv', sep=';')

# %%
notas.head()
# Out:
#      Aluno  Nota
# 0  Aluno 1     3
# 1  Aluno 2     4
# 2  Aluno 3     4
# 3  Aluno 4     4
# 4  Aluno 5     4

# %%
notas.describe()
# Out:
#            Nota
# count  50.00000
# mean    7.00000
# std     1.85164
# min     3.00000
# 25%     6.00000
# 50%     7.00000
# 75%     8.00000
# max    10.00000

# %%
df_distribuicao = pd.DataFrame()
df_distribuicao = notas.loc[:,'Nota'].value_counts().sort_index().to_frame()
df_distribuicao
# Out:
#     Nota
# 3      1
# 4      4
# 5      6
# 6      9
# 7     10
# 8      9
# 9      5
# 10     6

# %%
pop = pd.read_csv('arquivos/populacao1.csv', sep=';')

# %%
pop.describe()
# Out:
#                Ano  População total        Homens      Mulheres   Nascimentos  \
# count    51.000000     5.100000e+01  5.100000e+01  5.100000e+01     51.000000
# mean   2035.000000     3.728947e+06  1.812416e+06  1.916531e+06  42338.274510
# std      14.866069     2.050548e+05  9.510571e+04  1.099750e+05   5084.256327
# min    2010.000000     3.239939e+06  1.584137e+06  1.655802e+06  34353.000000
# 25%    2022.500000     3.599626e+06  1.753513e+06  1.846113e+06  37891.500000
# 50%    2035.000000     3.828342e+06  1.855435e+06  1.968092e+06  41929.000000
# 75%    2047.500000     3.891834e+06  1.887592e+06  2.004241e+06  46976.000000
# max    2060.000000     3.915401e+06  1.898879e+06  2.016774e+06  50858.000000
#
#              Óbitos  Taxa Bruta de Natalidade  Taxa Bruta de Mortalidade  \
# count     51.000000                 51.000000                  51.000000
# mean   32539.588235                 11.457647                   8.641569
# ...

# %%
pop.head()
# Out:
#     Ano  População total   Homens  Mulheres  Nascimentos  Óbitos  \
# 0  2010          3239939  1584137   1655802        49915   21068
# 1  2011          3271415  1598982   1672433        50858   21062
# 2  2012          3302720  1613743   1688977        49724   21155
# 3  2013          3332952  1627967   1704985        48992   21278
# 4  2014          3363084  1642156   1720928        49875   21441
#
#   Taxa de Crescimento Geométrico  Taxa Bruta de Natalidade  \
# 0                              x                     15.41
# 1                           0.97                     15.55
# 2                           0.96                     15.06
# 3                           0.92                     14.70
# 4                            0.9                     14.83
#
#    Taxa Bruta de Mortalidade  Esperança de Vida ao Nascer  ...  \
# 0                       6.50                        74.10  ...
# 1                       6.44                        74.41  ...
# ...

# %%
alturas = pd.read_csv('arquivos/alturas.csv', sep=',')

# %%
alturas
# Out:
#     Alturas  Frequencia
# 0       160           2
# 1       161           1
# 2       162           1
# 3       163           1
# 4       164           2
# 5       165           5
# 6       166           2
# 7       167           4
# 8       168           4
# 9       169           1
# 10      170           7
# 11      171           1
# 12      172           2
# 13      173           1
# 14      174           4
# 15      175           2
# 16      176           2
# 17      177           3
# 18      178           3
# 19      179           1
# 20      180           1
